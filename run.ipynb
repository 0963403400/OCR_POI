# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd '/content/drive/MyDrive/OCR_MTA/OCR_POI'
# Out:
# /content/drive/MyDrive/OCR_MTA/OCR_POI

# %%
ls
# Out:
# 'charset_size=207.txt'                  model_doi.py
#  checkpoints/                           __pycache__/
#  custom_keras_layers_doi.py             read_image.py
#  custom_keras_layers_inference_doi.py   read_tfrecord.py
#  data/                                  records/
#  dataset.py                             requirements.txt
#  gen_record.py                          resize_data.py
#  hparams_doi.py                         run.ipynb
#  label_back_1000_org.csv                train_doi.py

# %%
pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 127 kB 12.8 MB/s
# ...
#      |████████████████████████████████| 147 kB 69.2 MB/s
# ...
#      |████████████████████████████████| 114 kB 63.7 MB/s
# ...
#      |████████████████████████████████| 3.9 MB 53.7 MB/s
# ...
#      |████████████████████████████████| 2.9 MB 57.4 MB/s
# ...
#      |████████████████████████████████| 303 kB 77.4 MB/s
# ...
#      |████████████████████████████████| 50 kB 6.3 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 56.1 MB/s
# ...
#      |████████████████████████████████| 96 kB 5.7 MB/s
# ...
#      |████████████████████████████████| 11.6 MB 58.7 MB/s
# ...
#      |████████████████████████████████| 1.6 MB 55.5 MB/s
# ...
#      |████████████████████████████████| 20.1 MB 1.1 MB/s
# ...
#      |████████████████████████████████| 147 kB 61.4 MB/s
# ...
#      |████████████████████████████████| 49.5 MB 92 kB/s
# ...
#      |████████████████████████████████| 2.2 MB 54.6 MB/s
# ...

# %%
# !unzip '/content/drive/MyDrive/OCR_MTA/OCR_POI/data/data.zip' -d '/content/drive/MyDrive/OCR_MTA/OCR_POI/data'

# %%
# !python3 resize_data.py

# %%
cd '/content/drive/MyDrive/OCR_MTA/OCR_POI/data'
# Out:
# /content/drive/MyDrive/OCR_MTA/OCR_POI/data

# %%
ls
# Out:
# data.zip  pad_train/  raw_train/  raw_val/  unpad_valid/

# %%
import shutil
shutil.copyfile('/content/drive/MyDrive/OCR_MTA/OCR_POI/data/raw_val/label.txt','/content/drive/MyDrive/OCR_MTA/OCR_POI/data/unpad_valid/label.txt' )
shutil.copyfile('/content/drive/MyDrive/OCR_MTA/OCR_POI/data/raw_train/label.txt','/content/drive/MyDrive/OCR_MTA/OCR_POI/data/unpad_train/label.txt' )
shutil.copyfile('/content/drive/MyDrive/OCR_MTA/OCR_POI/data/raw_val/label.txt','/content/drive/MyDrive/OCR_MTA/OCR_POI/data/pad_valid/label.txt' )
shutil.copyfile('/content/drive/MyDrive/OCR_MTA/OCR_POI/data/raw_train/label.txt','/content/drive/MyDrive/OCR_MTA/OCR_POI/data/pad_train/label.txt' )
# Out:
# '/content/drive/MyDrive/OCR_MTA/OCR_POI/data/pad_train/label.txt'

# %%
# !python3 gen_record.py
"Change parameters to gen train/val record"
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
# image_encoded: 8088
# image_class:  [46, 87, 46, 206, 206, 206, 206, 206, 206, 206]
# image_encoded: 5667
# image_class:  [105, 145, 57, 206, 206, 206, 206, 206, 206, 206]
# image_encoded: 14197
# image_class:  [59, 51, 87, 63, 206, 206, 206, 206, 206, 206]
# image_encoded: 2949
# image_class:  [16, 4, 17, 206, 206, 206, 206, 206, 206, 206]
# image_encoded: 8091
# image_class:  [105, 52, 153, 57, 206, 206, 206, 206, 206, 206]
# image_encoded: 6970
# image_class:  [2, 48, 28, 42, 20, 4, 206, 206, 206, 206]
# image_encoded: 1116
# image_class:  [101, 206, 206, 206, 206, 206, 206, 206, 206, 206]
# image_encoded: 7058
# image_class:  [45, 131, 57, 50, 206, 206, 206, 206, 206, 206]
# image_encoded: 563
# image_class:  [5, 206, 206, 206, 206, 206, 206, 206, 206, 206]
# image_encoded: 12555
# image_class:  [57, 50, 88, 57, 206, 206, 206, 206, 206, 206]
# image_encoded: 13367
# ...

# %%
# !pip install numpy

# %%
# !python3 read_image.py

# %%
# !pip3 uninstall tensorflow

# %%
# !python3 read_image.py

# %%
# !python3 read_tfrecord.py

# %%
# !pip install tensorflow-gpu==2.3.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !python3 train_doi.py
# Out:
# 2022-08-16 07:32:35.826078: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2022-08-16 07:32:38.444289: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2022-08-16 07:32:38.500140: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-16 07:32:38.500766: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2022-08-16 07:32:38.500821: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
import cv2
from google.colab.patches import cv2_imshow
image = cv2.imread('/content/drive/MyDrive/OCR_MTA/images/img_1.jpg.png')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
# cv2_imshow(image)
print(gray.shape)
print(image.shape)
import numpy as np
img  = np.dstack((gray, gray, gray))
print(img.shape)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
# Out:
# (251, 201)
# (251, 201, 3)
# (251, 201, 3)

# %%
import tensorflow as tf
print(tf.__version__)
gray = tf.constant([[2,2],[2,3]])
print(gray.shape)
print(gray.numpy())
tmp = np.zeros((gray.shape[0], gray.shape[1], 3))
tmp = np.dstack((gray, gray, gray))
print(tmp.shape)
image = tf.constant(tmp)
print(type(image))
print(image.shape)
# Out:
# 2.3.0
# (2, 2)
# [[2 2]
#  [2 3]]
# (2, 2, 3)
# <class 'tensorflow.python.framework.ops.EagerTensor'>
# (2, 2, 3)
